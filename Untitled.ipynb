# %% [markdown]
# # 𝐂𝐒𝐄𝟏𝟏𝟏: 𝐏𝐫𝐨𝐠𝐫𝐚𝐦𝐦𝐢𝐧𝐠 𝐋𝐚𝐧𝐠𝐮𝐚𝐠𝐞 𝐈𝐈
#
# # Midterm Exam

# %% [markdown]
# Name: Shihab Shahriear Antor
#
# ID: 20301113
#
# Sec: 05
#
# G-suit: shihab.shahriear.antor@g.bracu.ac.bd

# %%
#Problem 01


my_tuple = (("Mominul", 1101),("Mustafiz", 1202),("Bell", 2101),("Cook", 
2103),("Smith", 3101),("Finch", 3102),("Starc", 3203), ("Imrul", 1103), 
("Taijul", 1204))


ban = {}
aus = {}
eng = {}

bba = ()
bbb = ()
eba = ()
ebb = ()
aba = ()
abb = ()
for i in my_tuple:
    x = str(i[1])

    if x[0] == '1':

        if x[1] == '1':
            bba = bba + (i[0],)
            ban['Batters'] = bba
        elif x[1] == '2':
            bbb = bbb + (i[0],)
            ban['Bowlers'] = bbb
        else:
            pass
    elif x[1] == '2':

        if x[1] == '1':
            eba = eba + (i[0],)
            eng['Batters'] = eba
        elif x[1] == '2':
            ebb = ebb + (i[0],)
            eng['Bowlers'] = ebb
        else:
            pass  
    elif x[0] == '3':

        if x[1] == '1':

            aba = aba + (i[0],)
            aus['Batters'] = aba
        elif x[1] == '2':

            abb = abb + (i[0],)
            aus['Bowlers'] = abb
        else:
            pass
            
dic1 = {
        "Bangladesh": ban,
        "England": eng,
        "Australia":aus
       
        }          
print(dic1)
# Out:
# {'Bangladesh': {'Batters': ('Mominul', 'Imrul'), 'Bowlers': ('Mustafiz', 'Taijul')}, 'England': {'Bowlers': ('Starc',)}, 'Australia': {'Batters': ('Smith', 'Finch')}}

# %%
#Problem 02



class TechShop:
    def __init__(self, name):
        self.name = name
        self.count = 0
        list1 = []
    def addProduct(self, *product):
        if product[2] == '':
            print("A product without code cannot be added.")
        else:
            print(f"Product with Code: {product[2]} added")
            self.count = self.count + 1
            list1.append(product)
    
    def printProducts(self):
        print("Total products:", self.count)
        for i in list1:
            print(f"Product name:{i[0]} Category:{i[1]} Product Code:{i[0]}")

class Product:
    def __init__(self, p_name, p_type = '', p_id = 0):
        self.name = p_name
        self.type = p_type
        self.id = p_id
        
    def __repr__(self):
        return self.name, self.type
    def __int__(self):
        return self.p_id

        
print(Product('a', 'b', 5))
obj = TechShop("Star Tech")
p1 = Product("Core i7 11700","Processor",16039)
print("=================================")
obj.addProduct(p1)
print("=================================")
obj.printProducts()
print("=================================")
p2 = Product("Ryzen 5900X","Processor")
p3 = Product("ASRock B550 Taichi","Motherboard",18080)
print("=================================")
obj.addProduct(p2,p3)
print("=================================")
obj.printProducts()
print("=================================")
p2.setCode(17699)
print("=================================")
obj.addProduct(p2)
print("=================================")
obj.printProducts()
print("=================================")
p4 = Product("ASUS ROG Strix Z390-F","Motherboard",8694)
p5 = Product("ASUS ROG Strix RTX3080","GPU",17071)
print("=================================")
obj.addProduct(p4,p5)
print("=================================")
obj.printProducts()
print("=================================")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9215b47500dd> in <module>
#      33
#      34
# ---> 35 print(Product('a', 'b', 5))
#      36 obj = TechShop("Star Tech")
#      37 p1 = Product("Core i7 11700","Processor",16039)
#
# TypeError: __str__ returned non-string (type tuple)

# %%
#Problem 02



class TechShop:
    def __init__(self, name):
        self.name = name
        self.count = 0
        self.list1 = []
    def addProduct(self, *product):
        
        for pr in product:
            pr = str(pr)
            pro = list(map(str, pr.split("#")))


            if pro[2] == "0":
                print("A product without code cannot be added.")
            else:
                print(f"Product with Code: {pro[2]} added")
                self.count = self.count + 1
                self.list1.append(pro)

    
    def printProducts(self):
        x = ["Product name:", "Category:", "Product Code:"]
        print("Total products:", self.count)
        for i in self.list1:
            for j in range(len(i)):
                print(f"{x[j]}: {i[j]}", end = "")
                # print(f"Category:{i[j+1]}", end = "")
                # print(f"Product Code:{j+2}")
                # break
        
            print()
            # print(f"Product name:{i[0]} Category:{i[1]} Product Code:{i[2]}")
            # break

class Product:
    def __init__(self, p_name ='', p_type = '', p_id = 0):
        pr_id = str(p_id)
        self.name = p_name
        self.type = p_type
        self.id = pr_id
    def setCode(self, id):
        id = str(id)
        self.id = id
        
    def __str__(self):
        return f"{self.name}#{self.type}#{self.id}"


#Product("5","t", 5)
obj = TechShop("Star Tech")
p1 = Product("Core i7 11700","Processor",16039)
print("=================================")
obj.addProduct(p1)
print("=================================")
obj.printProducts()
print("=================================")
p2 = Product("Ryzen 5900X","Processor")
p3 = Product("ASRock B550 Taichi","Motherboard",18080)
print("=================================")
obj.addProduct(p2,p3)
print("=================================")
obj.printProducts()
print("=================================")
p2.setCode(17699)
print("=================================")
obj.addProduct(p2)
print("=================================")
obj.printProducts()
print("=================================")
p4 = Product("ASUS ROG Strix Z390-F","Motherboard",8694)
p5 = Product("ASUS ROG Strix RTX3080","GPU",17071)
print("=================================")
obj.addProduct(p4,p5)
print("=================================")
obj.printProducts()
print("=================================")
# Out:
# ...
# Product with Code: 16039 added
# ...
# Total products: 1
# Product name:: Core i7 11700Category:: ProcessorProduct Code:: 16039
# ...
# A product without code cannot be added.
# Product with Code: 18080 added
# ...
# Total products: 2
# Product name:: Core i7 11700Category:: ProcessorProduct Code:: 16039
# Product name:: ASRock B550 TaichiCategory:: MotherboardProduct Code:: 18080
# ...
# Product with Code: 17699 added
# ...
# Total products: 3
# Product name:: Core i7 11700Category:: ProcessorProduct Code:: 16039
# Product name:: ASRock B550 TaichiCategory:: MotherboardProduct Code:: 18080
# Product name:: Ryzen 5900XCategory:: ProcessorProduct Code:: 17699
# ...
# Product with Code: 8694 added
# Product with Code: 17071 added
# ...
# Total products: 5
# Product name:: Core i7 11700Category:: ProcessorProduct Code:: 16039
# Product name:: ASRock B550 TaichiCategory:: MotherboardProduct Code:: 18080
# Product name:: Ryzen 5900XCategory:: ProcessorProduct Code:: 17699
# ...
